# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df_sales = pd.read_csv(r"C:\Users\65866\Downloads\2357220-Visualization_249_26102023_-_Suresh_Nagulavancha (1)\Sales_Data.csv")

# %%
df_sales
# Out:
#                                  Region               Country   Item_Type  \
# 0     Central America and the Caribbean  Antigua and Barbuda    Baby Food
# 1     Central America and the Caribbean                Panama      Snacks
# 2                                Europe        Czech Republic   Beverages
# 3                                  Asia           North Korea      Cereal
# 4                                  Asia             Sri Lanka      Snacks
# ...                                 ...                   ...         ...
# 4995              Australia and Oceania           New Zealand   Household
# 4996       Middle East and North Africa            Azerbaijan     Clothes
# 4997                               Asia               Myanmar   Baby Food
# 4998                             Europe               Finland     Clothes
# 4999                 Sub-Saharan Africa              Tanzania  Vegetables
#
#      Sales_Channel Order_Priority  Order_Date     Order_ID   Ship_Date  \
# ...

# %% [markdown]
# ## Line Plot using Pandas

# %%
df_sales[["Unit_MakingCost","Total_Cost"]].plot(x="Unit_MakingCost", y="Total_Cost", c="b", lw=5, marker="*", mfc="r", mec="c", ms=10)
plt.title("Unit_MakingCost vs Total_Cost")
plt.show()

# %%
## The above lineplot shows that comparision between Unit_MakingCost and Total_Cost.We can see that as the graph increases Unit_MakingCost gradually the Total_Cost also increases
## From the graph i can conclude that the Maximum Total_Cost increases with increase in Unit_MakingCost

# %% [markdown]
# ## Line Plot using Matplotlib

# %%
df_sales.columns
# Out:
# Index(['Region', 'Country', 'Item_Type', 'Sales_Channel', 'Order_Priority',
#        'Order_Date', 'Order_ID', 'Ship_Date', 'Units_Sold',
#        'Unit_SellingPrice', 'Unit_MakingCost', 'Total_Revenue', 'Total_Cost',
#        'Total_Profit'],
#       dtype='object')

# %%
plt.plot(df_sales["Units_Sold"].head(30), df_sales["Unit_SellingPrice"].head(30), label="Units",marker="P",mfc="r",mec="y",ms=10,lw=2)
plt.title("Units_Sold vs Unit_SellingPrice", loc="center",fontdict={'family':'sans','style':'italic','color':'blue', 'size':18})
plt.xlabel("Units_Sold")
plt.ylabel("Unit_SellingPrice")
plt.legend()
plt.grid()
plt.show()

# %%
# From above plot i conclude that most Units Sold happened from 2000-10000 units, however the highest selling price unit is around 620

# %% [markdown]
# ## Scatter Plot using Matplotlib

# %%
plt.scatter(df_sales["Total_Revenue"],df_sales["Total_Cost"], label="Total_Revenue vs Total_Cost", edgecolors="y",marker="p")
plt.title("Total_Revenue vs Total_Cost")
plt.xlabel("Total_Revenue")
plt.ylabel("Total_Cost")
plt.legend()
plt.grid()
plt.show()

# %%
# From above scatter plot i can conclude that as the Total_Cost increases gradually the Total_Revenue also increases

# %% [markdown]
# ## Histogram using Pandas

# %%
df_sales["Total_Revenue"].plot(kind="hist", bins=50)
# Out:
# <Axes: ylabel='Frequency'>

# %%
## From above Histogram i can conclude that most of data occurs between 0-1 and its frequency is high at 9000, however low at10

# %% [markdown]
# ## Histogram using Matplotlib

# %%
plt.hist(df_sales["Total_Cost"], bins=40)
plt.title("Units Sold")
plt.show()

# %%
## From above Histogram i conclude that most units sold is between 0-1**6, and the highest is 1200

# %% [markdown]
# ## Box Plots using Pandas

# %%
df_sales["Unit_SellingPrice"].plot.box(vert=False)
# Out:
# <Axes: >

# %%
# From above box plot i conclude that Units sold price at 25% is 100, 180 at 50% and 450 at 100%

# %% [markdown]
# ## Box plot using matplotlib

# %%
plt.boxplot(df_sales["Unit_MakingCost"], vert=False)
plt.show()

# %%
# From above box plot i conclude that Units sold price at 25% is 60, 110 at 50% and 300 at 100%

# %% [markdown]
# ## Pie charts Using Pandas

# %%
df_sales["Item_Type"].value_counts().plot(kind="pie")
# Out:
# <Axes: ylabel='Item_Type'>

# %%
# From above pie chart i conclude that every individual item shares almost an equal part

# %% [markdown]
# ## Pie charts Using Matplotlib

# %%
plt.pie(df_sales["Item_Type"].value_counts(, autopct="%.2f%%")
plt.title("Sales by Region")
plt.show()
# Out:
#   Cell In[36], line 1
#     plt.pie(df_sales["Item_Type"].value_counts(, autopct="%.2f%%")
#                                                ^
# SyntaxError: invalid syntax

# %% [markdown]
# ## Bar Plot using Pandas

# %%
df_sales["Item_Type"].value_counts().plot.bar()
# Out:
# <Axes: >

# %%
# From above bar plot i conclude that most types sales are Fruits, Beverages and Baby Food, however the least sales type is Clothes and all other are average sales

# %% [markdown]
# ## Bar Plot using Matplotlib

# %%
df_sales["Region"].value_counts()
# Out:
# Europe                               1330
# Sub-Saharan Africa                   1285
# Asia                                  719
# Middle East and North Africa          610
# Central America and the Caribbean     534
# Australia and Oceania                 416
# North America                         106
# Name: Region, dtype: int64

# %%
df_sales["Region"].nunique()
# Out:
# 7

# %%
df_sales["Region"].value_counts().plot(kind="bar")
plt.title("Region")
plt.xticks(ticks=range(1,7),rotation=90)
plt.show()

# %%
# From above bar plot i conclude that Sub-Saharan Africa is at top, North America being last, however remaining regions lie in the middle
